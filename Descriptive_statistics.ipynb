# %% [markdown]
# what is descriptive statistics?
#
# Descriptive statistics involves the collection, presentation, and characterization of a set of data in order to provide a clear and concise summary of its main features. It focuses on describing and summarizing the main aspects of a dataset without making any conclusions or inferences beyond the data itself.
#
# Objectives of Descriptive Statistics:
# Summarize Data: Descriptive statistics provide a summary of the main aspects of the data, such as central tendency (mean, median, mode), variability (range, variance, standard deviation), and distribution (skewness, kurtosis).
#
# Visualize Data: Descriptive statistics often use graphical representations, such as histograms, bar charts, pie charts, and scatter plots, to visually summarize and present the data.
#
# Identify Patterns and Trends: Descriptive statistics help in identifying any patterns, trends, or relationships within the data.
#
# Compare Data: Descriptive statistics can be used to compare different groups or subsets of data to understand similarities or differences between them.
#
# Common Descriptive Statistics Measures:
# Measures of Central Tendency:
#
# Mean: Average value of the dataset.
# Median: Middle value of the dataset.
# Mode: Most frequently occurring value(s) in the dataset.
# Measures of Variability:
#
# Range: Difference between the maximum and minimum values.
# Variance: Average of the squared differences from the mean.
# Standard Deviation: Square root of the variance; measures the average distance of the values from the mean.
# Measures of Distribution:
#
# Skewness: Measures the asymmetry of the data distribution.
# Kurtosis: Measures the "tailedness" or peakedness of the data distribution.
# Examples of Descriptive Statistics:
# Example 1:
# Consider a dataset of exam scores:
# Scores
# =
# [
# 85
# ,
# 90
# ,
# 92
# ,
# 88
# ,
# 95
# ]
# Scores=[85,90,92,88,95]
#
# Mean:
# 85
# +
# 90
# +
# 92
# +
# 88
# +
# 95
# 5
# =
# 90
# 5
# 85+90+92+88+95
# ​
#  =90
# Median: 90
# Mode: 90
# Range: 95 - 85 = 10
# Standard Deviation: Calculated using the formula and the mean.
# Example 2:
# Consider a dataset of ages of individuals:
# Ages
# =
# [
# 25
# ,
# 30
# ,
# 35
# ,
# 40
# ,
# 45
# ,
# 50
# ,
# 55
# ,
# 60
# ]
# Ages=[25,30,35,40,45,50,55,60]
#
# Mean:
# 25
# +
# 30
# +
# 35
# +
# 40
# +
# 45
# +
# 50
# +
# 55
# +
# 60
# 8
# =
# 42.5
# 8
# 25+30+35+40+45+50+55+60
# ​
#  =42.5
# Median: 42.5
# Mode: No mode as all values are unique.
# Range: 60 - 25 = 35
# Standard Deviation: Calculated using the formula and the mean.
# Summary:
# Descriptive statistics is a fundamental aspect of data analysis that provides a comprehensive summary of the main features of a dataset. It helps in understanding the data, identifying patterns and trends, and making informed decisions based on the summarized information. Descriptive statistics are often the first step in data analysis and are used to gain insights into the data before proceeding to inferential statistics or hypothesis testing.

# %%
scores =[ 85 , 90 , 92 , 88 , 95  ]
mean = 85+90+92+88+95/5 = 
meadian = 92
mode = no mode

# %% [markdown]
# Certainly! Central tendency refers to the measures that describe the center or typical value of a dataset. The main measures of central tendency are the mean, median, and mode. Each of these measures provides a different perspective on the central value of the data. Let's explore each measure with examples:
#
# 1. Mean
# Definition:
# The mean, also known as the average, is calculated by summing up all the values in a dataset and dividing by the number of values.
#
# Formula:
# Mean
# =
# Sum of all values
# Number of values
# Mean=
# Number of values
# Sum of all values
# ​
#
#
# Example:
# Consider the following dataset of exam scores:
# Scores
# =
# [
# 85
# ,
# 90
# ,
# 92
# ,
# 88
# ,
# 95
# ]
# Scores=[85,90,92,88,95]
#
# Mean
# =
# 85
# +
# 90
# +
# 92
# +
# 88
# +
# 95
# 5
# =
# 450
# 5
# =
# 90
# Mean=
# 5
# 85+90+92+88+95
# ​
#  =
# 5
# 450
# ​
#  =90
#
# 2. Median
# Definition:
# The median is the middle value in a dataset when the values are sorted in ascending or descending order. If there is an even number of values, the median is the average of the two middle values.
#
# Example:
# Using the same dataset of exam scores:
# Scores
# =
# [
# 85
# ,
# 90
# ,
# 92
# ,
# 88
# ,
# 95
# ]
# Scores=[85,90,92,88,95]
#
# First, sort the scores:
# Sorted Scores
# =
# [
# 85
# ,
# 88
# ,
# 90
# ,
# 92
# ,
# 95
# ]
# Sorted Scores=[85,88,90,92,95]
#
# Since there is an odd number of values (5), the median is the middle value:
# Median
# =
# 90
# Median=90
#
# 3. Mode
# Definition:
# The mode is the value that appears most frequently in a dataset. A dataset can have one mode (unimodal), two modes (bimodal), or more than two modes (multimodal).
#
# Example:
# Consider the following dataset of exam scores:
# Scores
# =
# [
# 85
# ,
# 90
# ,
# 92
# ,
# 88
# ,
# 90
# ]
# Scores=[85,90,92,88,90]
#
# In this dataset, the score 90 appears twice, which is more frequent than any other score.
# Mode
# =
# 90
# Mode=90
#
# Summary:
# Mean: The average value of a dataset; affected by extreme values (outliers).
#
# Example: Mean age of students in a class.
# Median: The middle value of a dataset; not affected by extreme values.
#
# Example: Median income in a population.
# Mode: The most frequently occurring value(s) in a dataset.
#
# Example: Mode of transportation used by commuters.
# Each measure of central tendency has its own strengths and weaknesses, and the choice of which measure to use depends on the nature of the data and the specific context of the analysis.

# %% [markdown]
# ## Measure of variability

# %% [markdown]
# Measures of variability, also known as measures of dispersion, provide information about the spread or dispersion of a dataset. They help to understand how spread out the values in the dataset are from the central value, such as the mean. Here are the main measures of variability along with examples and formulas:

# %% [markdown]
# 1. Range
# Definition:
# The range is the difference between the maximum and minimum values in a dataset.
#
# Formula:
# Range
# =
# Maximum Value
# −
# Minimum Value
# Range=Maximum Value−Minimum Value
#
# Example:
# Consider a dataset of exam scores:
#
# Scores=[85,90,92,88,95]
#
# Range=95−85=10
#
# 2. Variance
# Definition:
# Variance measures the average of the squared differences from the mean. It provides a measure of the spread of the dataset around the mean.
#
# Formula for Population Variance:
# ![DS cycle](variance_formula.jpg)
# n = number of data points
# Example:
# Using the same dataset of exam scores:
#
# Scores=[85,90,92,88,95]
#
# First, calculate the mean (
# �
# ˉ
# x
# ˉ
#  ):
# �
# ˉ
# =
# 85
# +
# 90
# +
# 92
# +
# 88
# +
# 95
# 5
# =
# 90
# x
# ˉ
#  =
# 5
# 85+90+92+88+95
# ​
#  =90
#
# Sample Variance:
# �
# 2
# =
# (
# 85
# −
# 90
# )
# 2
# +
# (
# 90
# −
# 90
# )
# 2
# +
# (
# 92
# −
# 90
# )
# 2
# +
# (
# 88
# −
# 90
# )
# 2
# +
# (
# 95
# −
# 90
# )
# 2
# 5
# −
# 1
# s
# 2
#  =
# 5−1
# (85−90)
# 2
#  +(90−90)
# 2
#  +(92−90)
# 2
#  +(88−90)
# 2
#  +(95−90)
# 2
#
# ​
#
# �
# 2
# =
# 25
# +
# 0
# +
# 4
# +
# 4
# +
# 25
# 4
# s
# 2
#  =
# 4
# 25+0+4+4+25
# ​
#
# �
# 2
# =
# 58
# 4
# s
# 2
#  =
# 4
# 58
# ​
#
# �
# 2
# =
# 14.5
# s
# 2
#  =14.5
#
# 3. Standard Deviation
# Definition:
# Standard deviation is the square root of the variance. It measures the average distance of the values from the mean and is in the same unit as the data.
#
# Formula for Population Standard Deviation:
# �
# =
# �
# 2
# σ=
# σ
# 2
#
# ​
#
#
# Formula for Sample Standard Deviation:
# �
# =
# �
# 2
# s=
# s
# 2
#
# ​
#
#
# Example:
# Using the variance calculated above for the exam scores dataset:
#
# Sample Standard Deviation:
# �
# =
# 14.5
# s=
# 14.5
# ​
#
# �
# ≈
# 3.81
# s≈3.81
#
# #### 4. Interquartile Range (IQR)
#
# The interquartile range (IQR) is the range between the first quartile (Q1) and the third quartile (Q3) of the dataset. It provides a measure of the spread of the middle 50% of the data.
#
# Formula:
# IQR=Q3−Q1
#
# Where:
#
# Q1 = First quartile (25th percentile)
#
# Q3 = Third quartile (75th percentile)
# Example:
# Consider a dataset of ages:
#
# Ages=[25,30,35,40,45,50,55,60]
#
# IQR:
# First, calculate Q1 and Q3:
#
# Q1=32.5
#
# Q3=52.5
#
# IQR=Q3−Q1=52.5−32.5=20
#
# Interquartile Range (IQR): Range between the first and third quartiles; measures the spread of the middle 50% of the data.
#
# These measures of variability provide valuable insights into the spread or dispersion of the data, complementing the measures of central tendency in describing the characteristics of a dataset.

# %%
Ages=[25,30,35,40,45,50,55,60]

q1 = 32.5
q2 = 52.5

IQR=Q3−Q1=52.5−32.5=20

# %% [markdown]
# ### Normal distribution:

# %% [markdown]
# The normal distribution, also known as the Gaussian distribution, is a continuous probability distribution characterized by a bell-shaped curve. It is defined by its mean (
# �
# μ) and standard deviation (
# �
# σ).
#
# is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean.

# %% [markdown]
# ![Noraml_distribution](normal_distribution.png)

# %% [markdown]
# The normal distribution is the proper term for a probability bell curve.
# 1. In a normal distribution, the mean is zero and the standard deviation is 1
# 2. It has zero skew and a kurtosis of 3
# 3. Normal distributions are symmetrical, but not all symmetrical distributions are normal.

# %% [markdown]
# The standard normal distribution has two parameters: the mean and the standard deviation. In a normal distribution, mean (average), median (midpoint), and mode (most frequent observation) are equal. These values represent the peak or highest point. The distribution then falls symmetrically around the mean, the width of which is defined by the standard deviation.

# %% [markdown]
# #### The Empirical Rule
# For all normal distributions, 68.2% of the observations will appear within plus or minus one standard deviation of the mean; 95.4% will fall within +/- two standard deviations; and 99.7% within +/- three standard deviations.
#
# This fact is sometimes called the "empirical rule," a heuristic that describes where most of the data in a normal distribution will appear. Data falling outside three standard deviations ("3-sigma") would signify rare occurrences.

# %% [markdown]
# ![](normal_distribution_empherical.png)

# %% [markdown]
# #### Skewness
# Skewness measures the degree of symmetry of a distribution. The normal distribution is symmetric and has a skewness of zero. If the distribution of a data set instead has a skewness less than zero, or negative skewness (left-skewness), then the left tail of the distribution is longer than the right tail; positive skewness (right-skewness) implies that the right tail of the distribution is longer than the left.

# %% [markdown]
# ![](skewness.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate skewed data
data_skewed = np.random.exponential(scale=2, size=1000)

# Apply log transformation
data_log = np.log(data_skewed)

# Plotting
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(data_skewed, bins=30, color='blue', alpha=0.7)
plt.title('Skewed Data')

plt.subplot(1, 2, 2)
plt.hist(data_log, bins=30, color='green', alpha=0.7)
plt.title('Log Transformed Data')

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Kurtosis
# Kurtosis measures the thickness of the tail ends of a distribution to the tails of a distribution. The normal distribution has a kurtosis equal to 3.0. Distributions with larger kurtosis greater than 3.0 exhibit tail data exceeding the tails of the normal distribution (e.g., five or more standard deviations from the mean).

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
